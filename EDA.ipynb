# %% [markdown]
# <div class="markdown-google-sans" style="text-align: center; max-width: 600px; margin: auto;">
#
#   # <b><span style='color:#E1B12D'>Exploratory Data Analysis</span></b>
#   ## BLI DATA
#
#   ---
#
#   <span style="color:#27AE60; font-size: 1.2em;"><b>Febriyan Chandra</b></span> — Project Manager
#   <span style="color:#2980B9; font-size: 1.2em;"><b>Ramadani Saputra</b></span> — Data Engineer
#   <span style="color:#8E44AD; font-size: 1.2em;"><b>I Putu Ferry Wistika</b></span> — Data Scientist
#
# </div>

# %% [markdown]
# # **Tentang Project**
#
# ## Deskripsi Proyek
# Proyek ini bertujuan untuk memanfaatkan Exploratory Data Analysis (EDA) dalam mengoptimalkan visibilitas dan strategi pemasaran untuk platform E-commerce.
# Dengan menganalisis data pelanggan, pola pembelian, dan tren pasar, proyek ini akan mengidentifikasi peluang pemasaran yang lebih efektif, meningkatkan konversi, dan memaksimalkan pengalaman pengguna.
# Fokus utama adalah memahami perilaku pelanggan melalui visualisasi data interaktif dan mengembangkan wawasan strategis untuk meningkatkan daya saing bisnis.

# %% [markdown]
# <a id=""></a>
# # <b><span style='color:#E1B12D'>Import Library</span></b>

# %%
from config import connection_database as conn
import pandas as pd
import seaborn as sns
from source import function as fungsi
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
# %matplotlib inline

# Set color palette for Seaborn
colors = ["#26536f", "#3b96b7", "#749ca8", "#b6a98d", "#c78a4d", "#854927"]
sns.set_palette(colors)

# %% [markdown]
# <a id=""></a>
# # <b><span style='color:#E1B12D'>Pipeline Koneksi Data Dari Server Postgree</span></b>

# %%
conn = conn.connect_to_database()
# Out:
# Connection to PostgreSQL successful!

# %% [markdown]
# <a id="A"></a>
# # <b>A. <span style='color:#E1B12D'>Ekstraksi Data</span></b>

# %%
# Daftar tabel
tables = [
    "customers",
    "geolocations",
    "order_items",
    "order_payments",
    "order_reviews",
    "orders",
    "payments",
    "products",
    "sellers",
    "full_data_ecommerce"
]

# Membaca setiap tabel dan membuat DataFrame
for table in tables:
    globals()[f"df_{table}"] = pd.read_sql(f"SELECT * FROM {table}", conn)
    print(f"DataFrame df_{table} berhasil dibuat.")
# Out:
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_49698/3827137298.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   globals()[f"df_{table}"] = pd.read_sql(f"SELECT * FROM {table}", conn)
# DataFrame df_customers berhasil dibuat.
# DataFrame df_geolocations berhasil dibuat.
# DataFrame df_order_items berhasil dibuat.
# DataFrame df_order_payments berhasil dibuat.
# DataFrame df_order_reviews berhasil dibuat.
# DataFrame df_orders berhasil dibuat.
# DataFrame df_payments berhasil dibuat.
# DataFrame df_products berhasil dibuat.
# DataFrame df_sellers berhasil dibuat.
# DataFrame df_full_data_ecommerce berhasil dibuat.

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 1 <span style='color:#E1B12D'>Ekstraksi Data - Customers </span></b>

# %%
fungsi.basic_eda(df_customers)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 99163 baris, 5 kolom
#
# Tipe data setiap kolom:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        customer_zip_code_prefix
# count              99163.000000
# mean               35057.887176
# std                29784.314664
# min                 1003.000000
# 25%                11320.000000
# 50%                24350.000000
# 75%                58406.500000
# max                99990.000000
#
#
# Info tambahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99163 entries, 0 to 99162
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 2 <span style='color:#E1B12D'>Ekstraksi Data - Geolocations </span></b>

# %%
fungsi.basic_eda(df_geolocations)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 19015 baris, 5 kolom
#
# Tipe data setiap kolom:
# zip_code_prefix        int64
# geolocation_lat      float64
# geolocation_lng      float64
# geolocation_city      object
# geolocation_state     object
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# zip_code_prefix      0
# geolocation_lat      0
# geolocation_lng      0
# geolocation_city     0
# geolocation_state    0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        zip_code_prefix  geolocation_lat  geolocation_lng
# count     19015.000000     19015.000000     19015.000000
# mean      42711.591901       -19.062087       -46.058008
# std       30905.051745         7.319402         5.380751
# min        1001.000000       -36.605374       -72.927296
# 25%       12721.500000       -23.564386       -49.000445
# 50%       38240.000000       -22.429252       -46.632544
# 75%       70656.500000       -15.615448       -43.255324
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 3 <span style='color:#E1B12D'>Ekstraksi Data - order_items </span></b>

# %%
fungsi.basic_eda(df_order_items)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 112096 baris, 7 kolom
#
# Tipe data setiap kolom:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        order_item_id            shipping_limit_date          price  \
# count  112096.000000                         112096  112096.000000
# mean        1.198036  2018-01-07 16:03:59.463138816     120.682327
# min         1.000000            2016-09-19 00:15:00       0.850000
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 4 <span style='color:#E1B12D'>Ekstraksi Data - order_payments </span></b>

# %%
fungsi.basic_eda(df_order_payments)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 103599 baris, 5 kolom
#
# Tipe data setiap kolom:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        payment_sequential  payment_installments  payment_value
# count       103599.000000         103599.000000  103599.000000
# mean             1.092848              2.853300     154.094637
# std              0.707495              2.687226     217.549810
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.785000
# 50%              1.000000              1.000000     100.000000
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 5 <span style='color:#E1B12D'>Ekstraksi Data - order_reviews </span></b>

# %%
fungsi.basic_eda(df_order_reviews)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 98895 baris, 5 kolom
#
# Tipe data setiap kolom:
# review_id                          object
# order_id                           object
# review_score                        int64
# review_creation_date               object
# review_answer_timestamp    datetime64[ns]
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# review_id                  0
# order_id                   0
# review_score               0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        review_score        review_answer_timestamp
# count  98895.000000                          98895
# mean       4.073229  2018-01-16 06:46:09.883816192
# min        1.000000            2016-10-07 18:32:00
# 25%        4.000000            2017-09-27 17:17:30
# 50%        5.000000            2018-02-05 05:41:00
# 75%        5.000000            2018-05-20 13:21:30
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 6 <span style='color:#E1B12D'>Ekstraksi Data - orders </span></b>

# %%
fungsi.basic_eda(df_orders)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 99163 baris, 8 kolom
#
# Tipe data setiap kolom:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date            object
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 159
# order_delivered_carrier_date     1776
# order_delivered_customer_date    2951
# order_estimated_delivery_date       0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 7 <span style='color:#E1B12D'>Ekstraksi Data - payments </span></b>

# %%
fungsi.basic_eda(df_payments)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 103599 baris, 5 kolom
#
# Tipe data setiap kolom:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        payment_sequential  payment_installments  payment_value
# count       103599.000000         103599.000000  103599.000000
# mean             1.092848              2.853300     154.094637
# std              0.707495              2.687226     217.549810
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.785000
# 50%              1.000000              1.000000     100.000000
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 8 <span style='color:#E1B12D'>Ekstraksi Data - products </span></b>

# %%
fungsi.basic_eda(df_products)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 32951 baris, 9 kolom
#
# Tipe data setiap kolom:
# product_id                     object
# product_category_name          object
# product_name_length           float64
# product_description_length    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# product_id                      0
# product_category_name           0
# product_name_length           610
# product_description_length    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        product_name_length  product_description_length  product_photos_qty  \
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 9 <span style='color:#E1B12D'>Ekstraksi Data - sellers </span></b>

# %%
fungsi.basic_eda(df_sellers)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 3088 baris, 4 kolom
#
# Tipe data setiap kolom:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object
#
#
# Jumlah baris duplikat: 0
#
# Jumlah nilai null per kolom:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64
#
#
# Statistik deskriptif (kolom numerik):
#        seller_zip_code_prefix
# count             3088.000000
# mean             32129.371762
# std              32640.223388
# min               1001.000000
# 25%               7083.500000
# 50%              14940.000000
# 75%              60970.250000
# max              99730.000000
#
#
# Info tambahan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3088 entries, 0 to 3087
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ...

# %% [markdown]
# <a id="A"></a>
# ## <b>A. 10 <span style='color:#E1B12D'>Ekstraksi Data - Merge All </span></b>

# %%
fungsi.basic_eda(df_full_data_ecommerce)
# Out:
# === EDA untuk DataFrame ===
# Dimensi data: 118492 baris, 37 kolom
#
# Tipe data setiap kolom:
# order_id                                 object
# customer_id                              object
# customer_unique_id                       object
# customer_zip_code_prefix                  int64
# customer_city                            object
# customer_state                           object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date            object
# order_item_id                           float64
# product_id                               object
# product_category_name                    object
# product_name_length                     float64
# product_description_length              float64
# product_photos_qty                      float64
# ...

# %% [markdown]
# <a id="B"></a>
# # <b>B. <span style='color:#E1B12D'>Exploratory Data Analysis(EDA) - All Data Ecommerce </span></b>

# %%
df = df_full_data_ecommerce

# %%
df.to_csv('full_data_ecommerce.csv', index=False)
print("DataFrame has been saved to 'full_data_ecommerce.csv'")
# Out:
# DataFrame has been saved to 'full_data_ecommerce.csv'

# %%
display(df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149  Akkarampalle
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149  Akkarampalle
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149  Akkarampalle
# 3  af07308b275d755c9edb36a90c618231                     47813     Pandariya
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265       Dhamdha
#
#    customer_state order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
df.describe().T
# Out:
#                                   count                           mean  \
# customer_zip_code_prefix       118492.0                   34951.399132
# order_purchase_timestamp         118492  2017-12-29 22:03:26.245316096
# order_approved_at                118316  2017-12-30 08:17:09.429324544
# order_delivered_carrier_date     116425  2018-01-03 11:42:26.719518976
# order_delivered_customer_date    115102  2018-01-12 23:57:52.119858944
# order_item_id                  117441.0                        1.19655
# product_name_length            115742.0                      48.754834
# product_description_length     115742.0                     786.421472
# product_photos_qty             115742.0                       2.201163
# product_weight_g               117421.0                    2112.104947
# product_length_cm              117421.0                      30.257535
# product_height_cm              117421.0                      16.643956
# ...

# %% [markdown]
# ## Splitting categorical & numerical features

# %%
df.describe().T
# Out:
#                                   count                           mean  \
# customer_zip_code_prefix       118492.0                   34951.399132
# order_purchase_timestamp         118492  2017-12-29 22:03:26.245316096
# order_approved_at                118316  2017-12-30 08:17:09.429324800
# order_delivered_carrier_date     116425  2018-01-03 11:42:26.719518720
# order_delivered_customer_date    115102  2018-01-12 23:57:52.119858688
# order_item_id                  117441.0                        1.19655
# product_name_length            115742.0                      48.754834
# product_description_length     115742.0                     786.421472
# product_photos_qty             115742.0                       2.201163
# product_weight_g               117421.0                    2112.104947
# product_length_cm              117421.0                      30.257535
# product_height_cm              117421.0                      16.643956
# ...

# %%
categorical_col = df.select_dtypes(include=['object']).columns
numerical_col = df.loc[:, ~df.columns.isin(['order_id', 'customer_id','customer_unique_id','order_item_id','product_id'])].select_dtypes(include=['int', 'float']).columns

print("Categorical columns: ", categorical_col)
print("Numerical columns: ", numerical_col)
# Out:
# Categorical columns:  Index(['order_id', 'customer_id', 'customer_unique_id', 'customer_city',
#        'customer_state', 'order_status', 'order_estimated_delivery_date',
#        'product_id', 'product_category_name', 'seller_id', 'seller_city',
#        'seller_state', 'review_id', 'review_creation_date', 'payment_type',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')
# Numerical columns:  Index(['customer_zip_code_prefix', 'product_name_length',
#        'product_description_length', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'review_score', 'payment_sequential', 'payment_installments',
#        'payment_value', 'geolocation_lat', 'geolocation_lng'],
#       dtype='object')

# %%
for cols in categorical_col:
  print(f"Categories in {cols}:", df[cols].unique())
# Out:
# Categories in order_id: ['1e7aff52cdbb2451ace09d0f848c3699' 'e481f51cbdc54678b7cc49136f2d6af7'
#  '53cdb2fc8bc7dce0b6741e2150273451' ... '5a9f106e9db0c818cee0c5c4a5efb352'
#  '402094e1d8f8b5f681f962bc2554345a' 'bfbd0f9bdef84302105ad712db648a6c']
# Categories in customer_id: ['ddaff536587109b89777e0353215e150' '9ef432eb6251297304e76186b10a928d'
#  'b0830fb4747a6c6d20dea0b8c802d7ef' ... 'b46b92545792b60cb001d909c3831ebe'
#  'a9cade3439281b14f81dbaa4ea56242c' '86dc2ffce2dfff336de2f386a786e574']
# Categories in customer_unique_id: ['c796780c7daeab9e94cc052b1f103b21' '7c396fd4830fd04220f754e42b4e5bff'
#  'af07308b275d755c9edb36a90c618231' ... 'b0229f62396effc36cfc54db9f5fba6a'
#  'b5fc114d1c1bbd091ee62a31110c56d2' '830d5b7aaa3b6f1e9ad63703bec97d23']
# Categories in customer_city: ['Bilgi' 'Akkarampalle' 'Pandariya' ... 'Mandawar' 'Sukdal' 'Kalghatgi']
# Categories in customer_state: ['Karnataka' 'Andhra Pradesh' 'Chhattisgarh' 'Punjab' 'Uttar Pradesh'
# ...

# %% [markdown]
# ## Data visualization

# %%
plt.figure(figsize=(15,17))
num_plots = len(numerical_col)
num_rows = (num_plots + 1) // 2

for index, column in enumerate(numerical_col):
    plt.subplot(num_rows, 3, index + 1)  # Adjusting for the number of rows and columns
    plt.subplots_adjust(wspace=0.2, hspace=0.5)
    sns.histplot(df[column],kde=True)
    plt.title(column)  # Use the column name as the title
    plt.xlabel(column.upper(), fontsize=14)
    plt.ylabel("count", fontsize=14)
plt.tight_layout(pad=1.0)
plt.show()

# %%
plt.figure(figsize=(20,25))
num_plots = len(numerical_col)
num_rows = (num_plots + 1) // 2

for index, column in enumerate(numerical_col):
    plt.subplot(num_rows, 3, index + 1)  # Adjusting for the number of rows and columns
    plt.subplots_adjust(wspace=0.2, hspace=0.5)
    sns.boxplot(df[column],color='green')
    plt.title(column)  # Use the column name as the title
    plt.xlabel(column.upper(), fontsize=14)
    plt.ylabel("count", fontsize=14)
plt.tight_layout(pad=1.0)
plt.show()

# %% [markdown]
# ## Univariate Analysis

# %%
# customer_zip_code_prefix
fungsi.UVA_numeric(df, ['customer_zip_code_prefix'])

# %%
#product_name_length
fungsi.UVA_numeric(df, ['product_name_length'])

# %%
#product_description_length	
fungsi.UVA_numeric(df, ['product_description_length'])

# %%
#product_photos_qty
fungsi.UVA_numeric(df, ['product_photos_qty'])

# %%
#product_weight_g
fungsi.UVA_numeric(df, ['product_weight_g'])

# %%
#product_length_cm
fungsi.UVA_numeric(df, ['product_length_cm'])

# %%
#product_height_cm
fungsi.UVA_numeric(df, ['product_height_cm'])

# %%
#product_width_cm
fungsi.UVA_numeric(df, ['product_width_cm'])

# %%
#review_score	
fungsi.UVA_numeric(df, ['review_score'])

# %%
#review_score	
fungsi.UVA_category(df, ['review_score'])

# %%
#payment_sequential
fungsi.UVA_numeric(df, ['payment_sequential'])

# %%
#payment_sequential
fungsi.UVA_category(df, ['payment_sequential'])

# %%
#payment_installments
fungsi.UVA_numeric(df, ['payment_installments'])

# %%
#payment_value
fungsi.UVA_numeric(df, ['payment_value'])

# %%
#geolocation_lat
fungsi.UVA_numeric(df, ['geolocation_lat'])

# %%
#geolocation_lng	
fungsi.UVA_numeric(df, ['geolocation_lng'])

# %%
#customer_state
fungsi.UVA_category(df, ['customer_state'])

# %%
#order_status	
fungsi.UVA_category(df, ['order_status'])

# %%
#payment_type
fungsi.UVA_category(df, ['payment_type'])

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Monthly Sales Trend (Line Plot)

# %%
# Monthly sales trend
monthly_sales = df.groupby(df['order_purchase_timestamp'].dt.to_period('M')).agg({'payment_value': 'sum'})

# Set the figure size for better visibility
plt.figure(figsize=(12, 6))

# Plot the data with custom colors
plt.plot(monthly_sales.index.astype(str), monthly_sales['payment_value'], 
         marker='o', linestyle='-', color=colors[0], linewidth=2)

# Adding titles and labels
plt.title('Monthly Sales Trend', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=14)
plt.ylabel('Total Sales', fontsize=14)

# Customize the ticks
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines for better readability
plt.grid(visible=True, linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Total Sales by Product Category (Bar Plot)

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Example: Orders by product category
top_categories = df['product_category_name'].value_counts().head(10)
top_categories.plot(kind='bar', color=colors[1], edgecolor='black')

# Adding titles and labels
plt.title('Top 10 Product Categories', fontsize=16, fontweight='bold')
plt.xlabel('Product Category', fontsize=14)
plt.ylabel('Number of Orders', fontsize=14)

# Customize ticks
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Proportion of Total Sales by Payment Type (Pie Chart)

# %%
# Set the figure size
plt.figure(figsize=(8, 8))

# Example: Proportion of total sales by payment type
sales_by_payment = df.groupby('payment_type')['payment_value'].sum()
sales_by_payment.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=colors)

# Adding title
plt.title('Sales Distribution by Payment Type', fontsize=16, fontweight='bold')

# Hide the y-label for better aesthetics
plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Review Scores (Histogram)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Example: Distribution of review scores
df['review_score'].hist(bins=5, color=colors[1], edgecolor='black')

# Adding titles and labels
plt.title('Distribution of Review Scores', fontsize=16, fontweight='bold')
plt.xlabel('Review Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
# Select relevant features for correlation analysis
correlation_features = df[numerical_col]

# Calculate the correlation matrix
correlation = correlation_features.corr()

# Define the custom colormap
custom_colors = ['#3B96B7', '#E9E5DC', '#C78A4D']
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", custom_colors)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap=custom_cmap, vmin=-1, vmax=1, fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Delivery Time by Product Category (Box Plot)

# %%
# Count the occurrences of each product category
category_counts = df['product_category_name'].value_counts()

# Set a threshold to decide which categories to keep
threshold = 3000  
common_categories = category_counts[category_counts >= threshold].index

# Create a new column for simplified categories
df['simplified_category'] = df['product_category_name'].where(df['product_category_name'].isin(common_categories), 'Other')

# %%
# plt.figure(figsize=(12, 8))

# # Horizontal box plot for delivery time by simplified product category
# sns.boxplot(x='order_delivered_customer_date', y='simplified_category', data=df, palette=colors)

# # Overlay swarm plot to show individual points
# sns.swarmplot(x='order_delivered_customer_date', y='simplified_category', data=df, color='k', alpha=0.6, size=3)

# # Adding titles and labels
# plt.title('Delivery Time by Product Category (Simplified)', fontsize=16, fontweight='bold')
# plt.xlabel('Delivery Time (Days)', fontsize=14)
# plt.ylabel('Product Category', fontsize=14)

# plt.grid(axis='x', linestyle='--', alpha=0.7)

# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pastikan kolom 'delivery_time_days' ada
df['delivery_time_days'] = (df['order_delivered_customer_date'] - df['order_purchase_timestamp']).dt.days

# Warna palet untuk kategori
colors = sns.color_palette("pastel")

plt.figure(figsize=(12, 8))

# Horizontal box plot for delivery time by simplified product category
sns.boxplot(x='delivery_time_days', y='simplified_category', data=df, palette=colors)

# Overlay swarm plot to show individual points
# sns.swarmplot(x='delivery_time_days', y='simplified_category', data=df, color='k', alpha=0.6, size=3)

# Adding titles and labels
plt.title('Delivery Time by Product Category (Simplified)', fontsize=16, fontweight='bold')
plt.xlabel('Delivery Time (Days)', fontsize=14)
plt.ylabel('Product Category', fontsize=14)

# Adding grid for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Adjust layout for better appearance
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/1149555249.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='delivery_time_days', y='simplified_category', data=df, palette=colors)
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/1149555249.py:13: UserWarning:
# The palette list has fewer values (10) than needed (15) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x='delivery_time_days', y='simplified_category', data=df, palette=colors)

# %% [markdown]
# ### Delivery Time by Day of the Week

# %%
# Pastikan kolom 'order_delivered_customer_date' adalah tipe datetime
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])

# Membuat kolom day_of_week_int
df['day_of_week_int'] = df['order_delivered_customer_date'].dt.dayofweek

# Jika Anda juga ingin nama hari dalam bentuk teks, tambahkan:
df['day_of_week_name'] = df['order_delivered_customer_date'].dt.day_name()

# Tampilkan beberapa baris untuk verifikasi
print(df[['order_delivered_customer_date', 'day_of_week_int', 'day_of_week_name']].head())
# Out:
#   order_delivered_customer_date  day_of_week_int day_of_week_name
# 0           2017-05-31 13:58:00              2.0        Wednesday
# 1           2017-10-10 21:25:00              1.0          Tuesday
# 2           2017-10-10 21:25:00              1.0          Tuesday
# 3           2017-10-10 21:25:00              1.0          Tuesday
# 4           2018-08-07 15:27:00              1.0          Tuesday

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=df, x='day_of_week_int', y='delivery_time_days', palette=colors)
plt.title('Delivery Time by Day of the Week', fontsize=16)
plt.xlabel('Day of the Week', fontsize=14)
plt.ylabel('Delivery Time (Days)', fontsize=14)
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/2422004566.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='day_of_week_int', y='delivery_time_days', palette=colors)
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/2422004566.py:2: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.violinplot(data=df, x='day_of_week_int', y='delivery_time_days', palette=colors)

# %% [markdown]
# ### Average Delivery Time by Month

# %%
# Create a new DataFrame for the monthly average delivery time
df['month_year'] = df['order_purchase_timestamp'].dt.to_period('M')
monthly_delivery_time = df.groupby('month_year')['delivery_time_days'].mean().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x='month_year', y='delivery_time_days', data=monthly_delivery_time, palette=colors)
plt.title('Average Delivery Time by Month', fontsize=16, fontweight='bold')
plt.xlabel('Month-Year', fontsize=14)
plt.ylabel('Average Delivery Time (Days)', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/1825137351.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='month_year', y='delivery_time_days', data=monthly_delivery_time, palette=colors)
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11744/1825137351.py:7: UserWarning:
# The palette list has fewer values (10) than needed (25) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='month_year', y='delivery_time_days', data=monthly_delivery_time, palette=colors)
