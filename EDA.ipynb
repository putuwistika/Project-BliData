# %% [markdown]
# <div class="markdown-google-sans" style="text-align: center; max-width: 600px; margin: auto;">
#
#   # <b><span style='color:#E1B12D'>Exploratory Data Analysis</span></b>
#   ## BLI DATA
#
#   ---
#
#   <span style="color:#27AE60; font-size: 1.2em;"><b>Febriyan Chandra</b></span> — Project Manager
#   <span style="color:#2980B9; font-size: 1.2em;"><b>Ramadani Saputra</b></span> — Data Engineer
#   <span style="color:#8E44AD; font-size: 1.2em;"><b>I Putu Ferry Wistika</b></span> — Data Scientist
#
# </div>

# %% [markdown]
# # **Tentang Project**
#
#
# nani nani nani

# %% [markdown]
# <a id=""></a>
# # <b><span style='color:#E1B12D'>Import Library</span></b>

# %%
from config import connection_database as conn
import pandas as pd

# %% [markdown]
# <a id=""></a>
# # <b><span style='color:#E1B12D'>Pipeline Koneksi Data Dari Server Postgree</span></b>

# %%
conn = conn.connect_to_database()
# Out:
# Connection to PostgreSQL successful!

# %% [markdown]
# <a id="A"></a>
# # <b>A. <span style='color:#E1B12D'>Ekstraksi Data</span></b>

# %%
# Nama tabel yang ingin dibuka
table_name = "full_data_ecommerce"  # Ganti dengan nama tabel yang lain

# Membaca tabel ke dalam Pandas DataFrame
df = pd.read_sql(f"SELECT * FROM {table_name}", conn)
# Out:
# /var/folders/8d/jpws5c3x0nzbnt38414wd8qc0000gn/T/ipykernel_11798/370583005.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT * FROM {table_name}", conn)

# %%
display(df)
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 118487  96a781796867d8c028ea1eedbd672e17  87f276c7f8462e63399bb1a70ea0496f
# 118488  675c52d8dfa16aa7a3b12b6ad7466fbb  7d4b050bcbcbf1f4c538c28a4d45842b
# 118489  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 118490  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 118491  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       7c396fd4830fd04220f754e42b4e5bff                      3149
# 1       7c396fd4830fd04220f754e42b4e5bff                      3149
# 2       7c396fd4830fd04220f754e42b4e5bff                      3149
# 3       af07308b275d755c9edb36a90c618231                     47813
# 4       3a653a41f6f9fc3d2a113cf8398680e8                     75265
# ...                                  ...                       ...
# 118487  22f5499bc63c8ebcacf51cf02585eb37                     13301
# 118488  cc71356617ae08a686129c3923ba9ed3                     88210
# 118489  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
# 118490  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
# 118491  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
#
#          customer_city  customer_state order_status order_purchase_timestamp  \
# 0         Akkarampalle  Andhra Pradesh    delivered      2017-10-02 10:56:00
# 1         Akkarampalle  Andhra Pradesh    delivered      2017-10-02 10:56:00
# 2         Akkarampalle  Andhra Pradesh    delivered      2017-10-02 10:56:00
# 3            Pandariya    Chhattisgarh    delivered      2018-07-24 20:41:00
# 4              Dhamdha    Chhattisgarh    delivered      2018-08-08 08:38:00
# ...                ...             ...          ...                      ...
# 118487       Holalkere       Karnataka    delivered      2017-06-01 13:52:00
# 118488  Kavisuryanagar          Orissa    delivered      2017-09-14 11:34:00
# 118489        Kandukur  Andhra Pradesh    delivered      2016-09-15 12:16:00
# 118490        Kandukur  Andhra Pradesh    delivered      2016-09-15 12:16:00
# 118491        Kandukur  Andhra Pradesh    delivered      2016-09-15 12:16:00
#
#          order_approved_at order_delivered_carrier_date  ...  \
# 0      2017-10-02 11:07:00          2017-10-04 19:55:00  ...
# 1      2017-10-02 11:07:00          2017-10-04 19:55:00  ...
# 2      2017-10-02 11:07:00          2017-10-04 19:55:00  ...
# 3      2018-07-26 03:24:00          2018-07-26 14:31:00  ...
# 4      2018-08-08 08:55:00          2018-08-08 13:50:00  ...
# ...                    ...                          ...  ...
# 118487 2017-06-01 14:05:00          2017-06-05 13:58:00  ...
# 118488 2017-09-14 11:50:00          2017-09-14 21:29:00  ...
# 118489 2016-09-15 12:16:00          2016-11-07 17:11:00  ...
# 118490 2016-09-15 12:16:00          2016-11-07 17:11:00  ...
# 118491 2016-09-15 12:16:00          2016-11-07 17:11:00  ...
#
#        review_creation_date review_answer_timestamp  payment_sequential  \
# 0                2017-10-11     2017-10-12 03:43:00                 2.0
# 1                2017-10-11     2017-10-12 03:43:00                 3.0
# 2                2017-10-11     2017-10-12 03:43:00                 1.0
# 3                2018-08-08     2018-08-08 18:37:00                 1.0
# 4                2018-08-18     2018-08-22 19:07:00                 1.0
# ...                     ...                     ...                 ...
# 118487           2017-06-07     2017-06-08 17:58:00                 1.0
# 118488           2017-09-27     2017-10-01 03:04:00                 1.0
# 118489           2016-10-06     2016-10-07 18:32:00                 NaN
# 118490           2016-10-06     2016-10-07 18:32:00                 NaN
# 118491           2016-10-06     2016-10-07 18:32:00                 NaN
#
#        payment_type payment_installments  payment_value  geolocation_lat  \
# 0           voucher                  1.0          18.59       -23.574809
# 1           voucher                  1.0           2.00       -23.574809
# 2       credit_card                  1.0          18.12       -23.574809
# 3               UPI                  1.0         141.46       -12.169860
# 4       credit_card                  3.0         179.12       -16.746337
# ...             ...                  ...            ...              ...
# 118487  credit_card                  1.0          60.75       -23.258035
# 118488  credit_card                  1.0          72.14       -27.154607
# 118489         None                  NaN            NaN       -20.581177
# 118490         None                  NaN            NaN       -20.581177
# 118491         None                  NaN            NaN       -20.581177
#
#         geolocation_lng  geolocation_city  geolocation_state
# 0            -46.587471      Akkarampalle     Andhra Pradesh
# 1            -46.587471      Akkarampalle     Andhra Pradesh
# 2            -46.587471      Akkarampalle     Andhra Pradesh
# 3            -44.988369         Pandariya       Chhattisgarh
# 4            -48.514624           Dhamdha       Chhattisgarh
# ...                 ...               ...                ...
# 118487       -47.294176         Holalkere          Karnataka
# 118488       -48.569866    Kavisuryanagar             Orissa
# 118489       -47.858931          Kandukur     Andhra Pradesh
# 118490       -47.858931          Kandukur     Andhra Pradesh
# 118491       -47.858931          Kandukur     Andhra Pradesh
#
# [118492 rows x 37 columns]
